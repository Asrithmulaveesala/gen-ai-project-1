# %%
print("hello world")
# Out:
# hello world

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
import streamlit as st

# %%
from langchain_community.llms import Ollama
llm=Ollama(model="gemma:2b")

# %%
llm.invoke("hi how are you")
# Out:
# 'Hello! I am doing well, thank you for asking. How are you doing today?'

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
prompt=ChatPromptTemplate.from_messages(
    [
        ("system","you are a helpful assistent .plz respond to the question asked"),
        ("user","question{question}")
    ]
)

# %%
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

# %%
input_text="give me indetail about the movie rrr"

# %%
if input_text:
    print(chain.invoke({"question":input_text}))
# Out:
# Sure, I can help you with that!
#
# **RRR** is a 2022 Indian historical action film directed by SS Rajamouli and starring Ram Charan, Jr., Jr. NTR, and Alia Bhatt. The film is a remake of the 2008 Telugu film of the same name.
#
# **Here are some key details about the movie:**
#
# * **Release date:** March 29, 2022 (India), April 13, 2022 (worldwide)
# * **Genre:** Historical fiction, action
# * **Director:** SS Rajamouli
# * **Starring:** Ram Charan, Jr., Jr. NTR, Alia Bhatt
# * **Plot summary:** The film depicts the true story of the Indian rebellion of 1942 against British colonial rule.
# * **Box office performance:** The film was a box office success in India, grossing over ₹660 crores.
# * **Critical reception:** The film received widespread critical acclaim, with many critics praising the performances of the cast, the direction, and the film's historical accuracy.
#
# **Some interesting facts about the movie:**
#
# * The film was filmed in a record-breaking 128 days.
# * The film features a song titled "Naatu Naatu", which became a global hit.
# * The film has been nominated for several awards, including the Academy Award for Best Foreign Language Film.
#
# **I hope this gives you a good overview of the movie RRR. If you have any other questions, please let me know.**
